# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob
import os

# %%
df.Omschrijving.value_counts().nlargest(10).plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e2cc6cb7044e> in <module>
# ----> 1 df.Omschrijving.value_counts().nlargest(10).plot.bar()
#
# NameError: name 'df' is not defined

# %%
df.Omschrijving.value_counts().nlargest(10).plot.pie()

# %%
df.Omschrijving.value_counts().nsmallest(10).plot.bar()

# %%
path =r'/Users/bartfranse/Desktop/NO_XXX_EVENT_EXPORT' 
allFiles = glob.glob(path + "/*.CSV")

list_ = []

for x in range (0,10000):
    file = allFiles[x]
    df = pd.read_csv(file,index_col=None, header=0, skiprows = 23, delimiter = ";", encoding = "mac_roman", low_memory=False)
    list_.append(df)

frame = pd.concat(list_, axis = 0, ignore_index = True)

# %%
frame.Omschrijving.value_counts()
# Out:
# Meteo Actuele Windrichting                                                                                4234200
# Meteo Actuele Windkracht                                                                                  3241438
# Meteo Gemiddelde Windrichting                                                                             2522210
# Meteo Gemiddelde Windkracht                                                                               1497042
# Meteo Actuele Temperatuur                                                                                  848229
# Algemeen Commando Proces Stoppen Bedienbaar                                                                595848
# Marifoon Status Ontvangen                                                                                  551317
# SFC Brug Stap Rust                                                                                         516973
# ...

# %%
frame.Omschrijving.value_counts().nlargest(20).plot.bar()

# %%
frame.Klasse.value_counts()
# Out:
# 1.0    32241
# 2.0     5687
# 5.0     1494
# 7.0      354
# 6.0      208
# Name: Klasse, dtype: int64

# %%
frame.Klasse.value_counts().plot.bar()

# %%
frame.Klasse.replace('', np.nan, inplace=True)
frame.dropna(subset=['Klasse'], inplace=True)
frame.Omschrijving.value_counts()
# Out:
# Brug Verzamelstoring                                                                                      1816
# Objectbewaking Alarm Niet Ingeschakeld                                                                    1494
# Brug Directe Stop                                                                                         1368
# Afsluitboom 2 Storing                                                                                     1285
# Afsluitboom 1 Storing                                                                                     1228
# Noodstop Actief                                                                                           1141
# Afsluitboom 2 Noodstop                                                                                     978
# Afsluitboom 1 Noodstop                                                                                     978
# ...

# %%
frame.Omschrijving.value_counts().nlargest(10).plot.bar()

# %%
klasse1 = frame.loc[frame['Klasse'] == 1.0]
klasse1.Omschrijving.value_counts()
klasse1.Omschrijving.value_counts().nlargest(10).plot.bar()

# %%
klasse2 = frame.loc[frame['Klasse'] == 2.0]
klasse2.Omschrijving.value_counts()
klasse2.Omschrijving.value_counts().nlargest(10).plot.bar()

# %%
#klasse3 = frame.loc[frame['Klasse'] == 3.0]
#klasse3.Omschrijving.value_counts()
#klasse3.Omschrijving.value_counts().nlargest(10).plot.bar()

# %%
klasse4 = frame.loc[frame['Klasse'] == 4.0]
klasse4.Omschrijving.value_counts()
klasse4.Omschrijving.value_counts().nlargest(10).plot.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-b5768819dfd6> in <module>
#       1 klasse4 = frame.loc[frame['Klasse'] == 4.0]
#       2 klasse4.Omschrijving.value_counts()
# ----> 3 klasse4.Omschrijving.value_counts().nlargest(10).plot.bar()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in bar(self, **kwds)
#    2781         axes : :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#    2782         """
# -> 2783         return self(kind='bar', **kwds)
#    2784
#    2785     def barh(self, **kwds):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
# ...

# %%
klasse5 = frame.loc[frame['Klasse'] == 5.0]
klasse5.Omschrijving.value_counts()
klasse5.Omschrijving.value_counts().nlargest(10).plot.bar()

# %%
klasse6 = frame.loc[frame['Klasse'] == 6.0]
klasse6.Omschrijving.value_counts()
klasse6.Omschrijving.value_counts().nlargest(10).plot.bar()

# %%
klasse7 = frame.loc[frame['Klasse'] == 7.0]
klasse7.Omschrijving.value_counts()
klasse7.Omschrijving.value_counts().nlargest(10).plot.bar()
