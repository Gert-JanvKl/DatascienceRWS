# %% [markdown]
# # Imports

# %%
import csv
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Reading file

# %%
df = pd.read_csv('NO_XXX_EVENT_EXPORT/NO_W5_EVENT_EXPORT_2015-12-02_00-00-00_2015-12-02_23-59-59.CSV', skiprows=23, delimiter=';', encoding = "mac_roman")

# %% [markdown]
# # Deleting all columns that are totally empty

# %%
df.dropna(how='all')
# Out:
#                          Tijd     Type  Klasse  \
# 0     02-12-2015 23:43:36.187   PROCES     NaN
# 1     02-12-2015 23:43:36.083   PROCES     NaN
# 2     02-12-2015 23:43:21.378   PROCES     NaN
# 3     02-12-2015 23:24:14.481   PROCES     NaN
# 4     02-12-2015 23:24:14.481   PROCES     NaN
# 5     02-12-2015 23:23:45.601   PROCES     NaN
# 6     02-12-2015 23:23:43.479   PROCES     NaN
# 7     02-12-2015 23:23:43.479   PROCES     NaN
# 8     02-12-2015 23:23:43.479   PROCES     NaN
# 9     02-12-2015 23:23:43.479   PROCES     NaN
# 10    02-12-2015 23:23:43.449   PROCES     NaN
# 11    02-12-2015 23:14:11.382   PROCES     NaN
# 12    02-12-2015 23:14:11.382   PROCES     NaN
# 13    02-12-2015 23:04:11.380   PROCES     NaN
# 14    02-12-2015 23:04:11.380   PROCES     NaN
# 15    02-12-2015 22:43:28.973   PROCES     NaN
# 16    02-12-2015 22:43:28.973   PROCES     NaN
# 17    02-12-2015 22:43:14.077   PROCES     NaN
# 18    02-12-2015 22:04:11.383   PROCES     NaN
# ...

# %%
df.head()
# Out:
#                       Tijd    Type  Klasse           Waarde  ID  \
# 0  02-12-2015 23:43:36.187  PROCES     NaN  4.0080366134644 NaN
# 1  02-12-2015 23:43:36.083  PROCES     NaN  4.0080051422119 NaN
# 2  02-12-2015 23:43:21.378  PROCES     NaN  4.0080761909485 NaN
# 3  02-12-2015 23:24:14.481  PROCES     NaN             TRUE NaN
# 4  02-12-2015 23:24:14.481  PROCES     NaN            FALSE NaN
#
#                                   Omschrijving  Status  Prioriteit  Cmnt.  \
# 0          Afsluitboom 1 Stilstands Uren Float     NaN         NaN    NaN
# 1          Afsluitboom 2 Stilstands Uren Float     NaN         NaN    NaN
# 2                   Object StilstandUren Float     NaN         NaN    NaN
# 3   Objectbewaking Inbraaksysteem Ingeschakeld     NaN         NaN    NaN
# 4  Objectbewaking Status Bezig Met Inschakelen     NaN         NaN    NaN
#
#    Tijd came  Tijd went  Tijd ack  Gebr.ID  \
# 0        NaN        NaN       NaN        0
# 1        NaN        NaN       NaN        0
# ...

# %%
plt.hist(df.head(100)['Type'], bins=30, histtype='barstacked')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.groupby('Type').mean()
# Out:
#          Klasse  ID  Status  Prioriteit  Cmnt.  Tijd came  Tijd went  \
# Type
# LOG-IN      NaN NaN     NaN         NaN    NaN        NaN        NaN
# LOG-UIT     NaN NaN     NaN         NaN    NaN        NaN        NaN
# PROCES      NaN NaN     NaN         NaN    NaN        NaN        NaN
#
#          Tijd ack       Gebr.ID  Unnamed: 14
# Type
# LOG-IN        NaN  31733.290323          NaN
# LOG-UIT       NaN   4097.000000          NaN
# PROCES        NaN    124.507901          NaN

# %%
df.Omschrijving.value_counts().nlargest(10).plot.bar()

# %%
df.Omschrijving.value_counts().nlargest(10).plot.pie()
