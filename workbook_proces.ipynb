# %%
import pandas as pd

# %%
if(os.getcwd().split('\')[-1] == "NO_XXX_EVENT_EXPORT"): #check if te woring directory is already set
    print("working directory already set")
else: #the directory needs to be changed
    os.chdir(os.getcwd()+"/NO_XXX_EVENT_EXPORT") # change the directory to the directory with the csvfiles
    print("working directory is set to: "+ os.getcwd())
# Out:
#   File "<ipython-input-12-3b6ee295b581>", line 1
#     if(os.getcwd().split('\')[-1] == "NO_XXX_EVENT_EXPORT"): #check if te woring directory is already set
#                                                                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
pd.read_csv(r"NO_XXX_EVENT_EXPORT/NO_W5_EVENT_EXPORT_2015-12-02_00-00-00_2015-12-02_23-59-59.CSV",usecols=[5], skiprows=23, delimiter=';')
# Out:
#                                            Omschrijving
# 0                   Afsluitboom 1 Stilstands Uren Float
# 1                   Afsluitboom 2 Stilstands Uren Float
# 2                            Object StilstandUren Float
# 3            Objectbewaking Inbraaksysteem Ingeschakeld
# 4           Objectbewaking Status Bezig Met Inschakelen
# 5                         NO_BRUG.COMMANDO.ALG_CMD_BITS
# 6                           NO_BRUG.STATUS.ALG_STS_BITS
# 7                    Objectbewaking Status Ingeschakeld
# 8            Objectbewaking Inbraaksysteem Uitschakelen
# 9           Objectbewaking Status Bezig Met Inschakelen
# 10                        NO_BRUG.COMMANDO.ALG_CMD_BITS
# 11    Brug Houddruk Pomp Inschakelen Terugmelding [A...
# 12                        Brug Houddrukpomp Inschakelen
# 13    Brug Houddruk Pomp Inschakelen Terugmelding [A...
# 14                        Brug Houddrukpomp Inschakelen
# 15                  Afsluitboom 1 Stilstands Uren Float
# 16                  Afsluitboom 2 Stilstands Uren Float
# 17                           Object StilstandUren Float
# 18    Brug Houddruk Pomp Inschakelen Terugmelding [A...
# 19                        Brug Houddrukpomp Inschakelen
# 20    Brug Houddruk Pomp Inschakelen Terugmelding [A...
# 21                        Brug Houddrukpomp Inschakelen
# 22                  Afsluitboom 1 Stilstands Uren Float
# 23                  Afsluitboom 2 Stilstands Uren Float
# 24                           Object StilstandUren Float
# 25                            SFC Brug Es Neer Vrijgave
# 26    Brug Hydrauliek Unit Accudruk Niet Hoog ( < 40...
# 27    Brug Houddruk Pomp Inschakelen Terugmelding [A...
# 28                        Brug Houddrukpomp Inschakelen
# 29    Brug Houddruk Pomp Inschakelen Terugmelding [A...
# ...                                                 ...
# 8006                                 Afstand: meekijken
# 8007                              Marifoon TX Indicatie
# 8008                              Marifoon RX Indicatie
# 8009                              Marifoon TX Indicatie
# 8010                              Marifoon TX Indicatie
# 8011                              Marifoon RX Indicatie
# 8012                              Marifoon RX Indicatie
# 8013                              Marifoon RX Indicatie
# 8014                              Marifoon RX Indicatie
# 8015  Brug Houddruk Pomp Inschakelen Terugmelding [A...
# 8016                      Brug Houddrukpomp Inschakelen
# 8017  Brug Houddruk Pomp Inschakelen Terugmelding [A...
# 8018                      Brug Houddrukpomp Inschakelen
# 8019                Afsluitboom 1 Stilstands Uren Float
# 8020                Afsluitboom 2 Stilstands Uren Float
# 8021                         Object StilstandUren Float
# 8022  Brug Hydrauliek Unit Accudruk Niet Hoog ( < 40...
# 8023                          SFC Brug Es Neer Vrijgave
# 8024  Brug Houddruk Pomp Inschakelen Terugmelding [A...
# 8025                      Brug Houddrukpomp Inschakelen
# 8026  Brug Houddruk Pomp Inschakelen Terugmelding [A...
# 8027                      Brug Houddrukpomp Inschakelen
# 8028                Afsluitboom 1 Stilstands Uren Float
# 8029                Afsluitboom 2 Stilstands Uren Float
# 8030                         Object StilstandUren Float
# 8031  Brug Houddruk Pomp Inschakelen Terugmelding [A...
# 8032                      Brug Houddrukpomp Inschakelen
# 8033                Afsluitboom 1 Stilstands Uren Float
# 8034                Afsluitboom 2 Stilstands Uren Float
# 8035                         Object StilstandUren Float
#
# [8036 rows x 1 columns]

# %%
df2 = pd.read_csv(csv_file, delimiter=';', skiprows=23, usecols=[5])
df2.drop_duplicates(subset=None, keep='first', inplace=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-86a124c68611> in <module>
# ----> 1 df2 = pd.read_csv(csv_file, delimiter=';', skiprows=23, usecols=[5])
#
# NameError: name 'csv_file' is not defined
